# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns

# %% [markdown]
# ### Reading data

# %%
data = pd.read_csv("Group1.xlsx - Group1.csv")
data.head()
# Out:
#     S1   S2   S3
# 0  450  366  382
# 1  435  372  389
# 2  441  368  378
# 3  448  371  381
# 4  442  371  372

# %% [markdown]
# ## Compute the covariance

# %%
covariance = data.cov()
covariance
# Out:
#             S1           S2           S3
# S1  403.333112   501.950304   512.664400
# S2  501.950304  3528.406081  2911.589497
# S3  512.664400  2911.589497  3778.218684

# %% [markdown]
# ## Compute the correlation coefficients

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
correlation = data.corr(method="pearson")
correlation
# Out:
#           S1        S2        S3
# S1  1.000000  0.420765  0.415296
# S2  0.420765  1.000000  0.797439
# S3  0.415296  0.797439  1.000000

# %% [markdown]
# ## Plot and report the relationships between the variables

# %%
data.plot()
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
sns.scatterplot(data)
# Out:
# <Axes: >

# %% [markdown]
# ## Generate a random sample of 50 observations for each sensor

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random
random_sample = data.sample(n=50)
random_sample
# Out:
#       S1   S2   S3
# 132  388  338  258
# 117  436  297  252
# 30   442  320  364
# 101  406  160  217
# 90   462  255  209
# 47   458  252  276
# 86   428  157  197
# 40   423  364  353
# 103  394  225  215
# 37   436  361  380
# 15   447  357  349
# 134  350  187  212
# 85   421  299  296
# 35   423  341  346
# 129  421  203  202
# 105  403  215  207
# 55   440  372  328
# 51   435  323  324
# 128  425  254  241
# 42   426  365  313
# 43   447  358  386
# 131  379  252  255
# 65   443  371  352
# 36   443  364  344
# 46   439  302  320
# 5    432  370  360
# 99   425  309  285
# 120  402  278  274
# 48   442  351  313
# 122  437  275  256
# 81   428  355  298
# 31   436  370  339
# 114  430  329  252
# 118  417  269  246
# 29   440  338  348
# 50   438  306  306
# 113  434  244  191
# 127  390  267  240
# 94   492  255  255
# 111  346  262  173
# 49   425  338  355
# 88   427  299  229
# 44   439  327  331
# 16   428  370  366
# 89   427  239  212
# 107  442  242  191
# ...

# %% [markdown]
# ## Compute the upper and the lower bounds with confidence intervals 90%, 95%, 99%

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example to find the z-score when the significance value or confidence level is given

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math

sample_mean = random_sample.mean()
sample_std = random_sample.std()
sample_size = random_sample.size
confidence_levels = [90,95,99]
significance_values = [0.1,0.05,0.01]
z_score = [1.64, 1.96, 2.58]

for i,j in zip(z_score, confidence_levels):
    LCL = sample_mean - i*(sample_std/math.sqrt(sample_size))
    UCL = sample_mean + i*(sample_std/math.sqrt(sample_size))
    print(f"For confidence level of {j}")
    print(f"Lower limit is {LCL}")
    print(f"Upper limit is {UCL}")
# Out:
# For confidence level of 90
# Lower limit is S1    422.503039
# S2    292.277015
# S3    278.374092
# dtype: float64
# Upper limit is S1    429.416961
# S2    308.482985
# S3    295.505908
# dtype: float64
# For confidence level of 95
# Lower limit is S1    421.828510
# S2    290.695945
# S3    276.702695
# dtype: float64
# Upper limit is S1    430.091490
# S2    310.064055
# S3    297.177305
# dtype: float64
# For confidence level of 99
# Lower limit is S1    420.521611
# S2    287.632622
# S3    273.464364
# dtype: float64
# Upper limit is S1    431.398389
# S2    313.127378
# S3    300.415636
# dtype: float64

# %%
### Calculating the population mean
data.mean()
# Out:
# S1    428.651852
# S2    304.837037
# S3    296.681481
# dtype: float64
