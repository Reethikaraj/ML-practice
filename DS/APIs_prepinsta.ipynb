# %% [markdown]
# API - Application Programming Interface - It is for 2 computer programs to communicate with each other.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# App -> request server

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Components of API:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
