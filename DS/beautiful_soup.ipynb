# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Using sample HTML code:

# %%
#Simple string stored in a variable called html
sample_html = '<!DOCTYPE html>\
<html>\
<head>\
    <title>PrepInsta Website</title>\
</head>\
<body>\
    <h1 class="mainHead">Welcome to PrepInsta</h1>\
    <p>This is a great website for us to prepare</p>\
    <h2 class="features">Overview</h2>\
    <p id="overview-text">What can you do on PrepInsta Website-</p>\
    <p class="features">You can Learn Skills</p>\
    <p class="features">You can Learn Coding</p>\
    <p class="features">You can Learn Languages</p>\
    <p class="features" id = "Apti">You can Learn Aptitiude</p>\
    <p class="features certification">You can get Certifications</p>\
    <h2>Certifications</h2>\
    <p class="features job">You can get a High Paying Job</p>\
    <p class="features" id="special-text">PrepInsta offers you the opportunity to learn without limits all the Upskilling Courses, Placement Preparation &  Certification Courses with Single Subscription</p>\
    <a id="linkweb" href="https://www.PrepInstaPrime.com">Visit PrepInstaPrime.com!</a>\
    <a href="https://prepinstaprime.com/purchase">Purchase Prime</a>\
    <a href="http://prepinstaprime.com/syllabus/tcs-nqt-syllabus">TCS NQT Course</a>\
    <a href="http://prepinstaprime.com/syllabus/machine-learning-and-aritifical-intelligence-syllabus">ML Course</a>\
</body>\
</html>'

# %%
type(sample_html)
# Out:
# str

# %%
from bs4 import BeautifulSoup

# %%
#converting a string to html
data = BeautifulSoup(sample_html, 'html.parser')
data
# Out:
# <!DOCTYPE html>
# ...

# %%
type(data)
# Out:
# bs4.BeautifulSoup

# %%
#Beautifying the format
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    PrepInsta Website
#   </title>
#  </head>
#  <body>
#   <h1 class="mainHead">
#    Welcome to PrepInsta
#   </h1>
#   <p>
#    This is a great website for us to prepare
#   </p>
#   <h2 class="features">
#    Overview
#   </h2>
#   <p id="overview-text">
#    What can you do on PrepInsta Website-
#   </p>
#   <p class="features">
#    You can Learn Skills
#   </p>
#   <p class="features">
#    You can Learn Coding
#   </p>
#   <p class="features">
#    You can Learn Languages
#   </p>
#   <p class="features" id="Apti">
#    You can Learn Aptitiude
#   </p>
#   <p class="features certification">
#    You can get Certifications
#   </p>
#   <h2>
#    Certifications
#   </h2>
#   <p class="features job">
#    You can get a High Paying Job
#   </p>
#   <p class="features" id="special-text">
# ...

# %%
#Pointing to a particular tag - html
data.html
# Out:
# <html><head> <title>PrepInsta Website</title></head><body> <h1 class="mainHead">Welcome to PrepInsta</h1> <p>This is a great website for us to prepare</p> <h2 class="features">Overview</h2> <p id="overview-text">What can you do on PrepInsta Website-</p> <p class="features">You can Learn Skills</p> <p class="features">You can Learn Coding</p> <p class="features">You can Learn Languages</p> <p class="features" id="Apti">You can Learn Aptitiude</p> <p class="features certification">You can get Certifications</p> <h2>Certifications</h2> <p class="features job">You can get a High Paying Job</p> <p class="features" id="special-text">PrepInsta offers you the opportunity to learn without limits all the Upskilling Courses, Placement Preparation &amp;  Certification Courses with Single Subscription</p> <a href="https://www.PrepInstaPrime.com" id="linkweb">Visit PrepInstaPrime.com!</a> <a href="https://prepinstaprime.com/purchase">Purchase Prime</a> <a href="http://prepinstaprime.com/syllabus/t
# ...

# %%
data.html.head
# Out:
# <head> <title>PrepInsta Website</title></head>

# %%
data.html.body.h1
# Out:
# <h1 class="mainHead">Welcome to PrepInsta</h1>

# %%
data.html.body.p
# Out:
# <p>This is a great website for us to prepare</p>

# %%
data.p
# Out:
# <p>This is a great website for us to prepare</p>

# %%
data.p.name #.name returns tag name
# Out:
# 'p'

# %%
data.p.string #.string returns the string in that tag
# Out:
# 'This is a great website for us to prepare'

# %%
data.p.attrs #.attrs returns the attributes in that particular tag
# Out:
# {}

# %%
data.h1.attrs
# Out:
# {'class': ['mainHead']}

# %%
data.a.get('id') #.get() method to get some info about the tag
# Out:
# 'linkweb'

# %%
data.a.get_text()
# Out:
# 'Visit PrepInstaPrime.com!'

# %%
data.find('p') #.find - gives the 1st tag available
# Out:
# <p>This is a great website for us to prepare</p>

# %%
data.find_all('p')
# Out:
# [<p>This is a great website for us to prepare</p>,
#  <p id="overview-text">What can you do on PrepInsta Website-</p>,
#  <p class="features">You can Learn Skills</p>,
#  <p class="features">You can Learn Coding</p>,
#  <p class="features">You can Learn Languages</p>,
#  <p class="features" id="Apti">You can Learn Aptitiude</p>,
#  <p class="features certification">You can get Certifications</p>,
#  <p class="features job">You can get a High Paying Job</p>,
#  <p class="features" id="special-text">PrepInsta offers you the opportunity to learn without limits all the Upskilling Courses, Placement Preparation &amp;  Certification Courses with Single Subscription</p>]

# %%
para_list = data.find_all('p')

for p in para_list:
    print("p" + str(para_list.index(p)) + ": " + p.string)
# Out:
# p0: This is a great website for us to prepare
# p1: What can you do on PrepInsta Website-
# p2: You can Learn Skills
# p3: You can Learn Coding
# p4: You can Learn Languages
# p5: You can Learn Aptitiude
# p6: You can get Certifications
# p7: You can get a High Paying Job
# p8: PrepInsta offers you the opportunity to learn without limits all the Upskilling Courses, Placement Preparation &  Certification Courses with Single Subscription

# %%
#returns in order of occurance
data.find_all(['p', 'h2', 'a'])
# Out:
# [<p>This is a great website for us to prepare</p>,
#  <h2 class="features">Overview</h2>,
#  <p id="overview-text">What can you do on PrepInsta Website-</p>,
#  <p class="features">You can Learn Skills</p>,
#  <p class="features">You can Learn Coding</p>,
#  <p class="features">You can Learn Languages</p>,
#  <p class="features" id="Apti">You can Learn Aptitiude</p>,
#  <p class="features certification">You can get Certifications</p>,
#  <h2>Certifications</h2>,
#  <p class="features job">You can get a High Paying Job</p>,
#  <p class="features" id="special-text">PrepInsta offers you the opportunity to learn without limits all the Upskilling Courses, Placement Preparation &amp;  Certification Courses with Single Subscription</p>,
#  <a href="https://www.PrepInstaPrime.com" id="linkweb">Visit PrepInstaPrime.com!</a>,
#  <a href="https://prepinstaprime.com/purchase">Purchase Prime</a>,
#  <a href="http://prepinstaprime.com/syllabus/tcs-nqt-syllabus">TCS NQT Course</a>,
# ...

# %%
data.find_all(class_ = 'features')
# Out:
# [<h2 class="features">Overview</h2>,
#  <p class="features">You can Learn Skills</p>,
#  <p class="features">You can Learn Coding</p>,
#  <p class="features">You can Learn Languages</p>,
#  <p class="features" id="Apti">You can Learn Aptitiude</p>,
#  <p class="features certification">You can get Certifications</p>,
#  <p class="features job">You can get a High Paying Job</p>,
#  <p class="features" id="special-text">PrepInsta offers you the opportunity to learn without limits all the Upskilling Courses, Placement Preparation &amp;  Certification Courses with Single Subscription</p>]

# %%
data.find_all('p', class_ = 'features')
# Out:
# [<p class="features">You can Learn Skills</p>,
#  <p class="features">You can Learn Coding</p>,
#  <p class="features">You can Learn Languages</p>,
#  <p class="features" id="Apti">You can Learn Aptitiude</p>,
#  <p class="features certification">You can get Certifications</p>,
#  <p class="features job">You can get a High Paying Job</p>,
#  <p class="features" id="special-text">PrepInsta offers you the opportunity to learn without limits all the Upskilling Courses, Placement Preparation &amp;  Certification Courses with Single Subscription</p>]

# %%
data.find_all(id = 'Apti')
# Out:
# [<p class="features" id="Apti">You can Learn Aptitiude</p>]

# %%
data.find_all('p', class_ = 'features', limit = 2)
# Out:
# [<p class="features">You can Learn Skills</p>,
#  <p class="features">You can Learn Coding</p>]

# %%
data.find_all(href = 'https://www.PrepInstaPrime.com')
# below wont work
# data.find_all(href="www.PrepInstaPrime.com")
# Out:
# [<a href="https://www.PrepInstaPrime.com" id="linkweb">Visit PrepInstaPrime.com!</a>]

# %%
import re #rejex

data.find_all(href = re.compile("Prep")) #Gives all the href with the word prep in it
# Out:
# [<a href="https://www.PrepInstaPrime.com" id="linkweb">Visit PrepInstaPrime.com!</a>]

# %%
data.find_all(href = re.compile('www'))
# Out:
# [<a href="https://www.PrepInstaPrime.com" id="linkweb">Visit PrepInstaPrime.com!</a>]

# %%
data.find_all('p', string=["You can Learn Coding", "You can Learn Skills", "You can Learn Languages"])
# Out:
# [<p class="features">You can Learn Skills</p>,
#  <p class="features">You can Learn Coding</p>,
#  <p class="features">You can Learn Languages</p>]

# %%
mylist = data.find_all('p')

for item in mylist:
    print(item.string)
# Out:
# This is a great website for us to prepare
# What can you do on PrepInsta Website-
# You can Learn Skills
# You can Learn Coding
# You can Learn Languages
# You can Learn Aptitiude
# You can get Certifications
# You can get a High Paying Job
# PrepInsta offers you the opportunity to learn without limits all the Upskilling Courses, Placement Preparation &  Certification Courses with Single Subscription

# %% [markdown]
# ### Relationship between tags:

# %%
html = '<!DOCTYPE html>\
<html>\
<head>\
<title>PrepInsta Website</title>\
</head>\
<body>\
<h1 class="mainHead">Welcome to PrepInsta</h1>\
<p>This is a great website for us to prepare</p>\
<p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p>\
<p>We wish you <b>All the best</b></p>\
<h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2>\
</body>\
</html>'

# %%
from bs4 import BeautifulSoup
data = BeautifulSoup(html, 'html.parser')
print(data.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    PrepInsta Website
#   </title>
#  </head>
#  <body>
#   <h1 class="mainHead">
#    Welcome to PrepInsta
#   </h1>
#   <p>
#    This is a great website for us to prepare
#   </p>
#   <p class="link">
#    This is a
#    <a href="https://prepinstaprime.com">
#     Link
#    </a>
#    to PrepInsta website
#   </p>
#   <p>
#    We wish you
#    <b>
#     All the best
#    </b>
#   </p>
#   <h2>
#    <a href="https://prepinsta.com/terms-and-conditions/">
#     Terms and Conditions
#    </a>
#   </h2>
#  </body>
# </html>

# %%
data.a
# Out:
# <a href="https://prepinstaprime.com">Link</a>

# %%
data.h2.a
# Out:
# <a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a>

# %%
data.find_all(True)
# Out:
# [<html><head><title>PrepInsta Website</title></head><body><h1 class="mainHead">Welcome to PrepInsta</h1><p>This is a great website for us to prepare</p><p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p><p>We wish you <b>All the best</b></p><h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2></body></html>,
#  <head><title>PrepInsta Website</title></head>,
#  <title>PrepInsta Website</title>,
#  <body><h1 class="mainHead">Welcome to PrepInsta</h1><p>This is a great website for us to prepare</p><p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p><p>We wish you <b>All the best</b></p><h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2></body>,
#  <h1 class="mainHead">Welcome to PrepInsta</h1>,
#  <p>This is a great website for us to prepare</p>,
# ...

# %%
p_list = data.find_all('p')

for p in p_list:
    print(p)
# Out:
# <p>This is a great website for us to prepare</p>
# <p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p>
# <p>We wish you <b>All the best</b></p>

# %%
p_list = data.find_all('p')

for p in p_list:
    print(p.string) #It will only print the text inside plain p tag. If there is anything else inside p, it will not print.
# Out:
# This is a great website for us to prepare
# None
# None

# %%
p_list = data.find_all('p')

for p in p_list:
    print(list(p.stripped_strings))
# Out:
# ['This is a great website for us to prepare']
# ['This is a', 'Link', 'to PrepInsta website']
# ['We wish you', 'All the best']

# %%
all_data_list = data.find_all(True)

tag_list = set()

for tag_data in all_data_list:
    if tag_data.name not in tag_list:
        tag_list.add(tag_data.name)

print("All the tags present: ", tag_list)
print(len(tag_list))
# Out:
# All the tags present:  {'body', 'p', 'h1', 'a', 'head', 'h2', 'html', 'title', 'b'}
# 9

# %%
#contents will give us immediate children
contents = data.html.contents
contents
# Out:
# [<head><title>PrepInsta Website</title></head>,
#  <body><h1 class="mainHead">Welcome to PrepInsta</h1><p>This is a great website for us to prepare</p><p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p><p>We wish you <b>All the best</b></p><h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2></body>]

# %%
# contents gets an iterator for the list and for child in title_tag. 
# children uses the iterator its been handed
# difference between contents and children
children = data.html.children

for child in children:
    print(child)
# Out:
# <head><title>PrepInsta Website</title></head>
# <body><h1 class="mainHead">Welcome to PrepInsta</h1><p>This is a great website for us to prepare</p><p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p><p>We wish you <b>All the best</b></p><h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2></body>

# %%
children = data.body.children

for child in children:
    print(child)
    
print(len(list(data.body.children)))
# Out:
# <h1 class="mainHead">Welcome to PrepInsta</h1>
# <p>This is a great website for us to prepare</p>
# <p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p>
# <p>We wish you <b>All the best</b></p>
# <h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2>
# 5

# %%
data.body.descendants #descendants = grand children
# Out:
# <generator object Tag.descendants at 0x0000023CC96AD1C0>

# %%
descendants_list = list(data.body.descendants)
#p.string is a child of p

for descendant in descendants_list:
    print(descendant)
    print("---------")
    
print(len(descendants_list))
# Out:
# <h1 class="mainHead">Welcome to PrepInsta</h1>
# ---------
# Welcome to PrepInsta
# ---------
# <p>This is a great website for us to prepare</p>
# ---------
# This is a great website for us to prepare
# ---------
# <p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p>
# ---------
# This is a
# ---------
# <a href="https://prepinstaprime.com">Link</a>
# ---------
# Link
# ---------
#  to PrepInsta website
# ---------
# <p>We wish you <b>All the best</b></p>
# ---------
# We wish you
# ---------
# <b>All the best</b>
# ---------
# All the best
# ---------
# <h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2>
# ---------
# <a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a>
# ---------
# Terms and Conditions
# ---------
# 16

# %%
descendants_list
# Out:
# [<h1 class="mainHead">Welcome to PrepInsta</h1>,
#  'Welcome to PrepInsta',
#  <p>This is a great website for us to prepare</p>,
#  'This is a great website for us to prepare',
#  <p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p>,
#  'This is a ',
#  <a href="https://prepinstaprime.com">Link</a>,
#  'Link',
#  ' to PrepInsta website',
#  <p>We wish you <b>All the best</b></p>,
#  'We wish you ',
#  <b>All the best</b>,
#  'All the best',
#  <h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2>,
#  <a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a>,
#  'Terms and Conditions']

# %%
parent = data.body.parent
parent
# Out:
# <html><head><title>PrepInsta Website</title></head><body><h1 class="mainHead">Welcome to PrepInsta</h1><p>This is a great website for us to prepare</p><p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p><p>We wish you <b>All the best</b></p><h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2></body></html>

# %%
parent = data.p.parent
parent
# Out:
# <body><h1 class="mainHead">Welcome to PrepInsta</h1><p>This is a great website for us to prepare</p><p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p><p>We wish you <b>All the best</b></p><h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2></body>

# %%
parent = data.b.parent
parent
# Out:
# <p>We wish you <b>All the best</b></p>

# %%
a_string = data.find(string = "Terms and Conditions")

a_string.find_parents()
# Out:
# [<a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a>,
#  <h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2>,
#  <body><h1 class="mainHead">Welcome to PrepInsta</h1><p>This is a great website for us to prepare</p><p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p><p>We wish you <b>All the best</b></p><h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2></body>,
#  <html><head><title>PrepInsta Website</title></head><body><h1 class="mainHead">Welcome to PrepInsta</h1><p>This is a great website for us to prepare</p><p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p><p>We wish you <b>All the best</b></p><h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2></body></html>,
#  <!DOCTYPE html>
# ...

# %%
a_string = data.find(string = "Terms and Conditions")

a_string.find_parents('body')
# Out:
# [<body><h1 class="mainHead">Welcome to PrepInsta</h1><p>This is a great website for us to prepare</p><p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p><p>We wish you <b>All the best</b></p><h2><a href="https://prepinsta.com/terms-and-conditions/">Terms and Conditions</a></h2></body>]

# %%
para = data.find("p", class_ = "link")
para
# Out:
# <p class="link">This is a <a href="https://prepinstaprime.com">Link</a> to PrepInsta website</p>

# %%
para.find_previous_sibling()
# Out:
# <p>This is a great website for us to prepare</p>
