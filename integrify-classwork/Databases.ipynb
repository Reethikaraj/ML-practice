# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Technical terms in database

# %% [markdown]
# * NoSQL = Non relational database, to store large data, No security.
# * SQL = Relational database = *** Focus of the course, ACID principles, query large database would slow down the system.
# * In memory = Small but quicker to relieve
# * disk-based = Large

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Transaction = Several operation in one go

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Entity - Place where we keep several data records - user entity, product entity, order entity
#
# Hierarchy of the database: (low to high)
# 1. Single record
# 2. Entity - Collection (NoSQL), Table(SQL) - 1 primary key per entity
# 3. Schema
# 4. Database
# 5. Collection of Database

# %% [markdown]
# #### Indexing

# %% [markdown]
# #### Data modelling

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Relationships between entities is shown above.
#
#
# Many to many is not recommended in Relational database. Instead of many to many, it's better to have a 3rd table which connects the 2 entities that has many to many relationship. This is called normalisation.
#
# Many to many relationship is demonstrated below between Junior devs and Tasks entities. We create a new entity(Junior-task) connecting them.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## MongoDB
#
# ##### Creating collection in mongo shell

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Inserting a collection:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Id would be assigned by the system in Mongodb
#
# * db.collectionName.find() - to find the collection

# %% [markdown]
# #### Finding the collection:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### To updateOne, delete:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### To Upsert: Update and insert:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### To deleteOne:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# To deleteMany:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PostgreSQL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Click on start button to activate the server.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### pgAdmin is the gui for postgreSQL

# %% [markdown]
# Never work with the default database. Always create a new database.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Create database
#
# create database nameOfTheDatabase

# %% [markdown]
# ![image.png](attachment:image.png)|

# %% [markdown]
# #### PgAdmin

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Connecting the database to PgAdmin

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hostname - local host, if we are using database in our system
#
# Port - same, don't touch
#
# Do not work with the default database, since it's difficult to ndelete it. Create a new database.

# %% [markdown]
# #### Creating the database:

# %% [markdown]
# database - right click - create -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Schema
#
# We can work with the default public schema or create our own.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Adding table to schema

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Naming convention for table
# lower case, plural nouns

# %% [markdown]
# #### Adding columns

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Searching with uuid is difficult - choose serial

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Updating a row

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Delete a row

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Data backup
# Todo

# %% [markdown]
# ### Indexing
# Todo
